# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Csv is sales in millions global

# %%
data = pd.read_csv('./PS4_GamesSales.csv')

# %%
data.head(10)
# Out:
#                              Game    Year             Genre  \
# 0              Grand Theft Auto V  2014.0            Action
# 1       Call of Duty: Black Ops 3  2015.0           Shooter
# 2           Red Dead Redemption 2  2018.0  Action-Adventure
# 3              Call of Duty: WWII  2017.0           Shooter
# 4                         FIFA 18  2017.0            Sports
# 5                         FIFA 17  2016.0            Sports
# 6                 Uncharted (PS4)  2016.0            Action
# 7                Spider-Man (PS4)  2018.0  Action-Adventure
# 8  Call of Duty: Infinite Warfare  2016.0           Shooter
# 9                       Fallout 4  2015.0      Role-Playing
#
#                         Publisher  North America  Europe  Japan  \
# 0                  Rockstar Games           6.06    9.71   0.60
# 1                      Activision           6.18    6.05   0.41
# 2                  Rockstar Games           5.26    6.21   0.21
# ...

# %%
data.isnull
# Out:
# <bound method DataFrame.isnull of                                     Game    Year             Genre  \
# 0                     Grand Theft Auto V  2014.0            Action
# 1              Call of Duty: Black Ops 3  2015.0           Shooter
# 2                  Red Dead Redemption 2  2018.0  Action-Adventure
# 3                     Call of Duty: WWII  2017.0           Shooter
# 4                                FIFA 18  2017.0            Sports
# ...                                  ...     ...               ...
# 1029  Fallen Legion: Flames of Rebellion     NaN      Role-Playing
# 1030            Radial G Racing Revolved  2017.0            Racing
# 1031                The Mummy Demastered     NaN            Action
# 1032          Project Nimbus: Code Mirai     NaN            Action
# 1033                 Battle Chef Brigade     NaN            Action
#
#            Publisher  North America  Europe  Japan  Rest of World  Global
# ...

# %%
data
# Out:
#                                     Game    Year             Genre  \
# 0                     Grand Theft Auto V  2014.0            Action
# 1              Call of Duty: Black Ops 3  2015.0           Shooter
# 2                  Red Dead Redemption 2  2018.0  Action-Adventure
# 3                     Call of Duty: WWII  2017.0           Shooter
# 4                                FIFA 18  2017.0            Sports
# ...                                  ...     ...               ...
# 1029  Fallen Legion: Flames of Rebellion     NaN      Role-Playing
# 1030            Radial G Racing Revolved  2017.0            Racing
# 1031                The Mummy Demastered     NaN            Action
# 1032          Project Nimbus: Code Mirai     NaN            Action
# 1033                 Battle Chef Brigade     NaN            Action
#
#            Publisher  North America  Europe  Japan  Rest of World  Global
# 0     Rockstar Games           6.06    9.71   0.60           3.02   19.39
# ...

# %%
data2 = data.dropna()

# %%
data2
# Out:
#                            Game    Year             Genre  \
# 0            Grand Theft Auto V  2014.0            Action
# 1     Call of Duty: Black Ops 3  2015.0           Shooter
# 2         Red Dead Redemption 2  2018.0  Action-Adventure
# 3            Call of Duty: WWII  2017.0           Shooter
# 4                       FIFA 18  2017.0            Sports
# ...                         ...     ...               ...
# 1025                  Biomutant  2019.0            Action
# 1026                    de Blob  2017.0          Platform
# 1027           Chaos on Deponia  2017.0         Adventure
# 1028                  Code Vein  2018.0            Action
# 1030   Radial G Racing Revolved  2017.0            Racing
#
#                        Publisher  North America  Europe  Japan  Rest of World  \
# 0                 Rockstar Games           6.06    9.71   0.60           3.02
# 1                     Activision           6.18    6.05   0.41           2.44
# ...

# %%
data2.drop(['North America', 'Europe', 'Japan', 'Rest of World'], axis=1, inplace=True)
# Out:
# /usr/local/lib/python3.9/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
data2
# Out:
#                            Game    Year             Genre  \
# 0            Grand Theft Auto V  2014.0            Action
# 1     Call of Duty: Black Ops 3  2015.0           Shooter
# 2         Red Dead Redemption 2  2018.0  Action-Adventure
# 3            Call of Duty: WWII  2017.0           Shooter
# 4                       FIFA 18  2017.0            Sports
# ...                         ...     ...               ...
# 1025                  Biomutant  2019.0            Action
# 1026                    de Blob  2017.0          Platform
# 1027           Chaos on Deponia  2017.0         Adventure
# 1028                  Code Vein  2018.0            Action
# 1030   Radial G Racing Revolved  2017.0            Racing
#
#                        Publisher  Global
# 0                 Rockstar Games   19.39
# 1                     Activision   15.09
# 2                 Rockstar Games   13.94
# 3                     Activision   13.40
# 4                      EA Sports   11.80
# ...

# %%
data2.dtypes
# Out:
# Game          object
# Year         float64
# Genre         object
# Publisher     object
# Global       float64
# dtype: object

# %%
data2 = data2.astype({'Year': 'int64'})

# %%
data2
# Out:
#                            Game  Year             Genre  \
# 0            Grand Theft Auto V  2014            Action
# 1     Call of Duty: Black Ops 3  2015           Shooter
# 2         Red Dead Redemption 2  2018  Action-Adventure
# 3            Call of Duty: WWII  2017           Shooter
# 4                       FIFA 18  2017            Sports
# ...                         ...   ...               ...
# 1025                  Biomutant  2019            Action
# 1026                    de Blob  2017          Platform
# 1027           Chaos on Deponia  2017         Adventure
# 1028                  Code Vein  2018            Action
# 1030   Radial G Racing Revolved  2017            Racing
#
#                        Publisher  Global
# 0                 Rockstar Games   19.39
# 1                     Activision   15.09
# 2                 Rockstar Games   13.94
# 3                     Activision   13.40
# 4                      EA Sports   11.80
# ...

# %%
data2 = data2[data2 != 0].dropna()

# %%
data2
# Out:
#                                  Game  Year             Genre  \
# 0                  Grand Theft Auto V  2014            Action
# 1           Call of Duty: Black Ops 3  2015           Shooter
# 2               Red Dead Redemption 2  2018  Action-Adventure
# 3                  Call of Duty: WWII  2017           Shooter
# 4                             FIFA 18  2017            Sports
# ..                                ...   ...               ...
# 707               Hyper Light Drifter  2017      Role-Playing
# 708                         Teslagrad  2014          Platform
# 709  Darius Burst: Chronicle Saviours  2017            Action
# 710   The Escapists: The Walking Dead  2016            Action
# 711                    Super Meat Boy  2016          Platform
#
#                Publisher  Global
# 0         Rockstar Games   19.39
# 1             Activision   15.09
# 2         Rockstar Games   13.94
# 3             Activision   13.40
# 4              EA Sports   11.80
# ...

# %%
data2.reset_index(drop=True, inplace=True)

# %%
data2
# Out:
#                                  Game  Year             Genre  \
# 0                  Grand Theft Auto V  2014            Action
# 1           Call of Duty: Black Ops 3  2015           Shooter
# 2               Red Dead Redemption 2  2018  Action-Adventure
# 3                  Call of Duty: WWII  2017           Shooter
# 4                             FIFA 18  2017            Sports
# ..                                ...   ...               ...
# 704               Hyper Light Drifter  2017      Role-Playing
# 705                         Teslagrad  2014          Platform
# 706  Darius Burst: Chronicle Saviours  2017            Action
# 707   The Escapists: The Walking Dead  2016            Action
# 708                    Super Meat Boy  2016          Platform
#
#                Publisher  Global
# 0         Rockstar Games   19.39
# 1             Activision   15.09
# 2         Rockstar Games   13.94
# 3             Activision   13.40
# 4              EA Sports   11.80
# ...

# %%
import matplotlib.pyplot as plt

# %%
data3 = data2.head(10)

# %%
plt.xticks(rotation=90)
plt.ylabel('Sales (in millions)')
plt.xlabel('Games')
plt.title('Top 10 Games Sold for PS4')
plt.bar(data3.Game, data3.Global)
plt.show()
